# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/isp/Documents/Major_Project/fake_job_postings.csv')

# %%
df.head(5)
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %%
df.shape
# Out:
# (17880, 18)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17880 entries, 0 to 17879
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   job_id               17880 non-null  int64
#  1   title                17880 non-null  object
#  2   location             17534 non-null  object
#  3   department           6333 non-null   object
#  4   salary_range         2868 non-null   object
#  5   company_profile      14572 non-null  object
#  6   description          17879 non-null  object
#  7   requirements         15184 non-null  object
#  8   benefits             10668 non-null  object
#  9   telecommuting        17880 non-null  int64
#  10  has_company_logo     17880 non-null  int64
#  11  has_questions        17880 non-null  int64
#  12  employment_type      14409 non-null  object
#  13  required_experience  10830 non-null  object
#  14  required_education   9775 non-null   object
# ...

# %%
df.describe()
# Out:
#              job_id  telecommuting  has_company_logo  has_questions  \
# count  17880.000000   17880.000000      17880.000000   17880.000000
# mean    8940.500000       0.042897          0.795302       0.491723
# std     5161.655742       0.202631          0.403492       0.499945
# min        1.000000       0.000000          0.000000       0.000000
# 25%     4470.750000       0.000000          1.000000       0.000000
# 50%     8940.500000       0.000000          1.000000       0.000000
# 75%    13410.250000       0.000000          1.000000       1.000000
# max    17880.000000       1.000000          1.000000       1.000000
#
#          fraudulent
# count  17880.000000
# mean       0.048434
# std        0.214688
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000

# %%
df.select_dtypes(include=['object','bool']).columns
# Out:
# Index(['title', 'location', 'department', 'salary_range', 'company_profile',
#        'description', 'requirements', 'benefits', 'employment_type',
#        'required_experience', 'required_education', 'industry', 'function'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# job_id                     0
# title                      0
# location                 346
# department             11547
# salary_range           15012
# company_profile         3308
# description                1
# requirements            2696
# benefits                7212
# telecommuting              0
# has_company_logo           0
# has_questions              0
# employment_type         3471
# required_experience     7050
# required_education      8105
# industry                4903
# function                6455
# fraudulent                 0
# dtype: int64

# %%
import seaborn
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
df.fillna(' ',inplace=True)

# %%
df.isna().sum()
# Out:
# job_id                 0
# title                  0
# location               0
# department             0
# salary_range           0
# company_profile        0
# description            0
# requirements           0
# benefits               0
# telecommuting          0
# has_company_logo       0
# has_questions          0
# employment_type        0
# required_experience    0
# required_education     0
# industry               0
# function               0
# fraudulent             0
# dtype: int64

# %%
df.drop(columns=['job_id','salary_range','telecommuting','has_company_logo','has_questions'],inplace = True)

# %%
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# ...

# %%
df['label']=df['fraudulent'].apply(lambda x:1 if x=='1' else 0)

# %%
df[df.fraudulent==1].title.value_counts()[:10]
# Out:
# title
# Data Entry Admin/Clerical Positions - Work From Home                    21
# Cruise Staff Wanted *URGENT*                                            21
# Home Based Payroll Typist/Data Entry Clerks Positions Available         21
# Customer Service Representative                                         17
# Administrative Assistant                                                16
# Home Based Payroll Data Entry Clerk Position - Earn $100-$200 Daily     12
# Account Sales Managers $80-$130,000/yr                                  10
# Payroll Data Coordinator Positions - Earn $100-$200 Daily               10
# Network Marketing                                                       10
# Payroll Clerk                                                           10
# Name: count, dtype: int64

# %%
df[df.fraudulent==0].title.value_counts()[:10]
# Out:
# title
# English Teacher Abroad                                311
# Customer Service Associate                            146
# Graduates: English Teacher Abroad (Conversational)    144
# English Teacher Abroad                                 95
# Software Engineer                                      86
# English Teacher Abroad (Conversational)                83
# Customer Service Associate - Part Time                 76
# Account Manager                                        73
# Web Developer                                          66
# Project Manager                                        62
# Name: count, dtype: int64

# %%
df['text'] = df['title']+" "+df['description']

# %%
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# ...

# %%
df['text'] = df['text'].str.lower()
df['text'] = df['text'].str.replace('[^a-zA-z0-9/s]','',regex=True)

# %%
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# ...

# %%
df.groupby('company_profile')['description'].sum()
# Out:
# company_profile
# ...

# %%
df.head()
# Out:
#                                        title            location department  \
# 0                           Marketing Intern    US, NY, New York  Marketing
# 1  Customer Service - Cloud Video Production      NZ, , Auckland    Success
# 2    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3          Account Executive - Washington DC  US, DC, Washington      Sales
# 4                        Bill Review Manager  US, FL, Fort Worth
#
#                                      company_profile  \
# 0  We're Food52, and we've created a groundbreaki...
# 1  90 Seconds, the worlds Cloud Video Production ...
# 2  Valor Services provides Workforce Solutions th...
# 3  Our passion for improving quality of life thro...
# 4  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# 0  Food52, a fast-growing, James Beard Award-winn...
# 1  Organised - Focused - Vibrant - Awesome!Do you...
# ...

# %%
df.plot(kind='bar')
plt.xlabel('company_profile')
plt.ylabel('description')
plt.title('grouped bar chart')
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df.plot(kind='bar')
#       2 plt.xlabel('company_profile')
#       3 plt.ylabel('description')
#
# File c:\Users\isp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_core.py:1030, in PlotAccessor.__call__(self, *args, **kwargs)
#    1027             label_name = label_kw or data.columns
#    1028             data.columns = label_name
# -> 1030 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File c:\Users\isp\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# ...

# %%
df.groupby('department')['employment_type'].sum()
# Out:
# department
#                                  Full-time  Full-timePart-timeFull-timeFull-ti...
#  \tCorporate Shared Services                                            Full-time
#  Lower Level Management
#  Marketing                                                              Full-time
#  Moni Technologies                                                      Temporary
#                                                       ...
# warehouse                                             Full-timeFull-timeFull-time
# web development
# Área Comercial
# ΕΜΠΟΡΙΚΟ                                                                Full-time
# ΠΛΗΡΟΦΟΡΙΚΗ                                                             Full-time
# Name: employment_type, Length: 1337, dtype: object

# %%
df.groupby(['benefits','required_experience']).agg({'industry':'sum'}).sort_values(by='industry')
# Out:
#                                                                                                       industry
# benefits                                           required_experience
# Salary and/or stock options depending on the sk...
# Paid position in a growing companyOpportunity t...
# Paid position in a growing companyOpportunity t...
# Paid position in a growing companyOpportunity t...
# Paid time off403(b) with employer matchPaid tra... Not Applicable
# ...                                                                                                        ...
# Ample paid time off (a.k.a. PTO) so you can fin... Associate                               Writing and Editing
# 4 Weeks of VacationHealth Benefits Attractive/F... Entry level                             Writing and Editing
# The main benefit of working at UVOCorp agency i... Not Applicable                          Writing and Editing
# ...

# %%
df['function'].value_counts()
# Out:
# function
#                           6455
# Information Technology    1749
# Sales                     1468
# Engineering               1348
# Customer Service          1229
# Marketing                  830
# Administrative             630
# Design                     340
# Health Care Provider       338
# Other                      325
# Education                  325
# Management                 317
# Business Development       228
# Accounting/Auditing        212
# Human Resources            205
# Project Management         183
# Finance                    172
# Consulting                 144
# Writing/Editing            132
# Art/Creative               132
# Production                 116
# Product Management         114
# Quality Assurance          111
# Advertising                 90
# Business Analyst            84
# Data Analyst                82
# Public Relations            76
# Manufacturing               74
# General Business            68
# ...

# %%
x = df['text']
y = df['label']
x,y
# Out:
# (0        marketinginternfood52afastgrowingjamesbeardawa...
#  1        customerservicecloudvideoproductionorganisedfo...
#  2        commissioningmachineryassistantcmaourclientloc...
#  3        accountexecutivewashingtondcthecompanyesrienvi...
#  4        billreviewmanagerjobtitleitemizationreviewmana...
#                                 ...
#  17875    accountdirectordistributionjustincasethisisthe...
#  17876    payrollaccountantthepayrollaccountantwillfocus...
#  17877    projectcostcontrolstaffengineercostcontrolexpt...
#  17878    graphicdesignernemsiastudiosislookingforanexpe...
#  17879    webapplicationdeveloperswhoarewevendisanawardw...
#  Name: text, Length: 17880, dtype: object,
#  0        0
#  1        0
#  2        0
#  3        0
#  4        0
#          ..
#  17875    0
#  17876    0
#  17877    0
#  17878    0
#  17879    0
#  Name: label, Length: 17880, dtype: int64)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((12516,), (5364,))

# %%
y_train.shape,y_test.shape
# Out:
# ((12516,), (5364,))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf = TfidfVectorizer(max_features = 3000)
x_train_tfidf = tfidf.fit_transform(x_train)
x_test_tfidf = tfidf.transform(x_test)

# %%
import joblib
from sklearn.feature_extraction.text import TfidfVectorizer

# Create a TfidfVectorizer with the same configuration used during training
vectorizer = TfidfVectorizer(max_features=3000)

# Fit the vectorizer on the training data (x_train)
# Assuming x_train contains your text data (like job descriptions, titles, etc.)
x_train_tfidf = vectorizer.fit_transform(x_train)

# Save the vectorizer
joblib.dump(vectorizer, 'vectorizer.pkl')
# Out:
# ['vectorizer.pkl']

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rfc = RandomForestClassifier(n_estimators = 100, random_state=42)
Rfc.fit(x_train_tfidf,y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = Rfc.predict(x_test_tfidf)
y_pred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
accuracy = accuracy_score(y_test,y_pred)
print("accuracy is: ",accuracy)
# Out:
# accuracy is:  1.0

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      5364
#
#     accuracy                           1.00      5364
#    macro avg       1.00      1.00      1.00      5364
# weighted avg       1.00      1.00      1.00      5364

# %%
cm = confusion_matrix(y_test,y_pred)
# Out:
# c:\Users\isp\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\metrics\_classification.py:409: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %%
cm

# %%
feature_importances = Rfc.feature_importances_
features = tfidf.get_feature_names_out()
features

# %%
joblib.dump(Rfc, 'model.pkl')
# Out:
# ['model.pkl']

# %%
import joblib

# Load the trained model and vectorizer
model = joblib.load('C:/Users/isp/Documents/Major_Project/model.pkl')  # Replace with your model path
vectorizer = joblib.load('C:/Users/isp/Documents/Major_Project/vectorizer.pkl')  # This is the vectorizer you just saved

# Define the input data
title = "Senior data analyst"
description = "Describe and manipulate data sets, sources, and structures. Develop reports to make data more meaningful to business initiatives, analyze data quantitatively and qualitatively and communicate findings."

# Preprocess the input text
def preprocess_text(title, description):
    input_text = title + " " + description
    input_text = input_text.lower()  # Example of preprocessing (convert to lowercase)
    return input_text

input_data = preprocess_text(title, description)

# Transform the input data using the loaded vectorizer
input_vector = vectorizer.transform([input_data])  # Input data needs to be in a list

# Predict whether the job posting is real or fake
prediction = model.predict(input_vector)

# Display the prediction result
if prediction == 1:
    print("The job posting is real.")
else:
    print("The job posting is fake.")
# Out:
# The job posting is fake.

# %%
import pandas as pd
print(pd.Series(y_train).value_counts())  # Check class distribution in training data
# Out:
# label
# 0    12516
# Name: count, dtype: int64

# %%
import joblib

# Load the trained model and vectorizer
model = joblib.load('C:/Users/isp/Documents/Major_Project/model.pkl')  # Replace with your model path
vectorizer = joblib.load('C:/Users/isp/Documents/Major_Project/vectorizer.pkl')  # This is the vectorizer you just saved

# Define the input data
title = "Senior data analyst"
description = "Describe and manipulate data sets, sources, and structures. Develop reports to make data more meaningful to business initiatives, analyze data quantitatively and qualitatively and communicate findings."

# Preprocess the input text
def preprocess_text(title, description):
    input_text = title + " " + description
    input_text = input_text.lower()  # Example of preprocessing (convert to lowercase)
    return input_text

input_data = preprocess_text(title, description)

# Transform the input data using the loaded vectorizer
input_vector = vectorizer.transform([input_data])  # Input data needs to be in a list

# Predict whether the job posting is real or fake
prediction = model.predict(input_vector)

# Display the prediction result
if prediction == 1:
    print("The job posting is real.")
else:
    print("The job posting is fake.")
# Out:
# The job posting is fake.
